# %% [markdown]
# Primeira etapa vamos carregar os dados dos dois conjuntos, teste e treinamento.
#
# Lembre-se que você precisa adicionar os arquivos CSV ao disco do server alocado toda vez que for executar esse notebook.
#
# <<<<<<<<<<< AQUI DO LADO !!!!!!!

# %%
import pandas as pd


titanic_train = pd.read_csv('/content/train.csv')
titanic_test = pd.read_csv('/content/test.csv')

titanic_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# Aqui podemos analisar as colunas que o dataset carregou.

# %%
#Descrição das colunas:
#  PassengerId : unique id number to each passenger
#  Survived : passenger survived(1) or died(0)
#  Pclass : passenger class
#  Name : name
#  Sex : gender of passenger
#  Age : age of passenger
#  SibSp : number of siblings or spouses
#  Parch : number of parent or children
#  Ticket : amount of money spend of ticket
#  Fare : fare of ticket
#  Cabin : cabin category
#  Embarked : port where passenger embarked(C= Cherbourg, S=Southampton Q)
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   AgeCat       714 non-null    category
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: category(1), float64(2), int64(5), object(5)
# memory usage: 84.7+ KB

# %%
#Exibindo uma descrição estatística simples
titanic_train.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# Sempre é importante avaliarmos que colunas possuem valores NULOS, ou não definidos.

# %%
#Lista a quantidade de nulls por coluna ---------------------------------------
titanic_train.isnull().sum()
print(titanic_train.shape)
# Out:
# (891, 12)

# %% [markdown]
# Agora iniciamos a etapa mais importante de todas as etapas do trabalho com dados, engenharia de features.
#
#
# Trabalhamos aqui nos 4 Cs
# 1. Correcting
# 2. Completing
# 3. Creating
# 4. Converting

# %%
#Lista a quantidade de nulls por coluna ---------------------------------------
print(titanic_train.isnull().sum())
print("-"*80)
print(titanic_test.isnull().sum())
print("-"*80)
#Faz uma breve descrição estatística do dataset -------------------------------
print(titanic_train.describe(include = 'all'))
print("-"*80)
print(titanic_test.describe(include = 'all'))
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# AgeCat         177
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# --------------------------------------------------------------------------------
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# AgeCat          86
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# --------------------------------------------------------------------------------
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# ...

# %% [markdown]
# Trabalhando para eliminar os NaN de Age:
# 1. Eliminar os registros
# 2. Usar a média.
# 3. Usar mediana.
# 4. Idade Artificial -1
# 5. Extraindo de outra feature
# 6. Random Forest prever idade

# %%
#Criando uma nova coluna de categoria com o CUT.
bins = [0,3,12,17,65,1000]
labels = ['Baby/Infant','Child','Teen','Adult','Elderly']

category = pd.cut(
                titanic_train['Age'],
                bins=bins,
                labels=labels
                )
titanic_train.insert(5,'AgeCat',category)

category = pd.cut(
                titanic_test['Age'],bins=bins,
                labels=labels
                )
titanic_test.insert(4,'AgeCat',category)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-1f52010d96dc> in <cell line: 10>()
#       8                 labels=labels
#       9                 )
# ---> 10 titanic_train.insert(5,'AgeCat',category)
#      11
#      12 category = pd.cut(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert AgeCat, already exists

# %%
titanic_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# Extraindo os pronomes de tratamento e comparando com a categoria de idade

# %%
titanic_train.insert(5,'Title', titanic_train['Name'].str.extract(' ([A-Za-z]+)\.', expand=False) )
titanic_test.insert(4,'Title', titanic_test['Name'].str.extract(' ([A-Za-z]+)\.', expand=False) )

# %%
titanic_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# Vamos brincar um pouco com os dados.

# %%
crosstab_title_age_train = pd.crosstab(titanic_train['Title'], titanic_train['AgeCat'])
print(crosstab_title_age_train)
print("-"*80)
crosstab_title_sex = pd.crosstab(titanic_train['Title'], titanic_train['Sex'])
print(crosstab_title_sex)
print("-"*80)
crosstab_title_survived = pd.crosstab(titanic_train['AgeCat'],titanic_train['Survived'])
crosstab_title_survived['TaxaMortalidade'] = crosstab_title_survived[0] / (crosstab_title_survived[0]+crosstab_title_survived[1])
print(crosstab_title_survived)
print("-"*80)
agesnull = titanic_train[titanic_train['Age'].isna()]
crosstab_title_agenull = pd.crosstab(agesnull['Title'], agesnull['Sex'])
print(crosstab_title_agenull)
# Out:
# AgeCat    Baby/Infant  Child  Teen  Adult  Elderly
# Title
# Capt                0      0     0      0        1
# Col                 0      0     0      2        0
# Countess            0      0     0      1        0
# Don                 0      0     0      1        0
# Dr                  0      0     0      6        0
# Jonkheer            0      0     0      1        0
# Lady                0      0     0      1        0
# Major               0      0     0      2        0
# Master             18     18     0      0        0
# Miss               12     20    19     95        0
# Mlle                0      0     0      2        0
# Mme                 0      0     0      1        0
# Mr                  0      1    21    369        7
# Mrs                 0      0     4    104        0
# Ms                  0      0     0      1        0
# Rev                 0      0     0      6        0
# Sir                 0      0     0      1        0
# ...

# %% [markdown]
# Agora vamos realmente preencher o campo do dataset

# %%
#Baseado na crosstab Title vs Age
titleXages_dict = { 'Capt'     : 'Elderly',
                    'Col'      : 'Adult',
                    'Countess' : 'Adult',
                    'Don'      : 'Adult',
                    'Dona'     : 'Adult', #Só encontrado em test
                    'Dr'       : 'Adult',
                    'Jonkheer' : 'Adult',
                    'Lady'     : 'Adult',
                    'Major'    : 'Adult',
                    'Master'   : 'Child',
                    'Miss'     : 'Adult', #Aqui temos trabalho ainda por fazer
                    'Mlle'     : 'Adult',
                    'Mme'      : 'Adult',
                    'Mr'       : 'Adult', #Aqui temos trabalho ainda por fazer, porém é menos importante que Miss
                    'Mrs'      : 'Adult', #Aqui podemos realmente ignorar o trabalho por fazer
                    'Ms'       : 'Adult',
                    'Rev'      : 'Adult',
                    'Sir'      : 'Adult'}

#Para toda chave no Dict de Pronomes de Tratamento, se a Idade foi NaN sete a
#categoria da idade para o definidio no Dict
for key in titleXages_dict:
    titanic_train.loc[(titanic_train['Age'].isna()) & (titanic_train['Title'] == key), 'AgeCat'  ] = titleXages_dict[key]
    titanic_test.loc[(titanic_test['Age'].isna()) & (titanic_test['Title'] == key), 'AgeCat'  ] = titleXages_dict[key]

#Confirmamos que todas as idades foram preenchidas
print(titanic_train.isnull().sum())
print(titanic_test.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Title            0
# AgeCat           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Title            0
# AgeCat           0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# No caso do porto que embarcaram, faltam apenas 2 elementos. Podemos usar a moda para preencher.

# %%
titanic_train['Embarked'].fillna(titanic_train['Embarked'].mode()[0], inplace = True)

# %% [markdown]
# Criamos um atributo chamado FamilySize. Ele é baseado nas colunas SibSp e Parch. Sendo 1 quando a pessoa está viajando sozinha.

# %%
titanic_train['FamilySize'] = titanic_train['SibSp'] + titanic_train['Parch'] + 1
titanic_test['FamilySize'] = titanic_test['SibSp'] + titanic_test['Parch'] + 1

# %% [markdown]
# Continuando sobre número de pessoas viajando em conjunto criamos um novo atributo para pessoas que viajam só.

# %%
titanic_train['IsAlone'] = 1
titanic_train['IsAlone'].loc[titanic_train['FamilySize'] > 1] = 0
titanic_test['IsAlone'] = 1
titanic_test['IsAlone'].loc[titanic_test['FamilySize'] > 1] = 0
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# Semelhante com o que fizemos com a variável contínua de Idade, vamos criar categorias para Fare (Valor da passagem).
#
# ATENÇAO - O dataset tem algumas inconsistências em relação ao valor da passagem que precisam de tratamento. Aqui ignoramos por questões didáticas.

# %%
#Continuous variable bins; qcut vs cut: https://stackoverflow.com/questions/30211923/what-is-the-difference-between-pandas-qcut-and-pandas-cut
#Fare Bins/Buckets using qcut or frequency bins: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.qcut.html
titanic_train['FareBin'] = pd.qcut(titanic_train['Fare'], 4)
titanic_test['FareBin'] = pd.qcut(titanic_test['Fare'], 4)

# %% [markdown]
# Agora começamos a transformar os valores para algo que os modelos podem tratar.
#
# Primiero vamos transofrmar todas as categorias em números.

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
titanic_train['Sex_Code'] = label.fit_transform(titanic_train['Sex'])
titanic_train['Age_Code'] = label.fit_transform(titanic_train['AgeCat'])
titanic_train['Embarked_Code'] = label.fit_transform(titanic_train['Embarked'])
titanic_train['Title_Code'] = label.fit_transform(titanic_train['Title'])
titanic_train['Fare_Code'] = label.fit_transform(titanic_train['FareBin'])

# %%
titanic_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
###############################################################################
# Explorando os dados
###############################################################################


#IMPORTANT: Intentionally plotted different ways for learning purposes only.

#optional plotting w/pandas: https://pandas.pydata.org/pandas-docs/stable/visualization.html

#we will use matplotlib.pyplot: https://matplotlib.org/api/pyplot_api.html

#to organize our graphics will use figure: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html#matplotlib.pyplot.figure
#subplot: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html#matplotlib.pyplot.subplot
#and subplotS: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html?highlight=matplotlib%20pyplot%20subplots#matplotlib.pyplot.subplots

#graph distribution of quantitative data
plt.figure(figsize=[16,12])

plt.subplot(231)
plt.boxplot(x=titanic_train['Fare'], showmeans = True, meanline = True)
plt.title('Fare Boxplot')
plt.ylabel('Fare ($)')

plt.subplot(232)
plt.boxplot(titanic_train['Age'], showmeans = True, meanline = True)
plt.title('Age Boxplot')
plt.ylabel('Age (Years)')

plt.subplot(233)
plt.boxplot(titanic_train['FamilySize'], showmeans = True, meanline = True)
plt.title('Family Size Boxplot')
plt.ylabel('Family Size (#)')

plt.subplot(234)
plt.hist(x = [titanic_train[titanic_train['Survived']==1]['Fare'], titanic_train[titanic_train['Survived']==0]['Fare']],
         stacked=True, color = ['g','r'],label = ['Survived','Dead'])
plt.title('Fare Histogram by Survival')
plt.xlabel('Fare ($)')
plt.ylabel('# of Passengers')
plt.legend()

plt.subplot(235)
plt.hist(x = [titanic_train[titanic_train['Survived']==1]['Age'], titanic_train[titanic_train['Survived']==0]['Age']],
         stacked=True, color = ['g','r'],label = ['Survived','Dead'])
plt.title('Age Histogram by Survival')
plt.xlabel('Age (Years)')
plt.ylabel('# of Passengers')
plt.legend()

plt.subplot(236)
plt.hist(x = [titanic_train[titanic_train['Survived']==1]['FamilySize'], titanic_train[titanic_train['Survived']==0]['FamilySize']],
         stacked=True, color = ['g','r'],label = ['Survived','Dead'])
plt.title('Family Size Histogram by Survival')
plt.xlabel('Family Size (#)')
plt.ylabel('# of Passengers')
plt.legend()




#we will use seaborn graphics for multi-variable comparison: https://seaborn.pydata.org/api.html

#graph individual features by survival
fig, saxis = plt.subplots(2, 3,figsize=(16,12))

sns.barplot(x = 'Embarked', y = 'Survived', data=titanic_train, ax = saxis[0,0])
sns.barplot(x = 'Pclass', y = 'Survived', order=[1,2,3], data=titanic_train, ax = saxis[0,1])
sns.barplot(x = 'IsAlone', y = 'Survived', order=[1,0], data=titanic_train, ax = saxis[0,2])

sns.pointplot(x = 'FareBin', y = 'Survived',  data=titanic_train, ax = saxis[1,0])
sns.pointplot(x = 'Age_Code', y = 'Survived',  data=titanic_train, ax = saxis[1,1])
sns.pointplot(x = 'FamilySize', y = 'Survived', data=titanic_train, ax = saxis[1,2])


#graph distribution of qualitative data: Pclass
#we know class mattered in survival, now let's compare class and a 2nd feature
fig, (axis1,axis2,axis3) = plt.subplots(1,3,figsize=(14,12))

sns.boxplot(x = 'Pclass', y = 'Fare', hue = 'Survived', data = titanic_train, ax = axis1)
axis1.set_title('Pclass vs Fare Survival Comparison')

sns.violinplot(x = 'Pclass', y = 'Age', hue = 'Survived', data = titanic_train, split = True, ax = axis2)
axis2.set_title('Pclass vs Age Survival Comparison')

sns.boxplot(x = 'Pclass', y ='FamilySize', hue = 'Survived', data = titanic_train, ax = axis3)
axis3.set_title('Pclass vs Family Size Survival Comparison')


#graph distribution of qualitative data: Sex
#we know sex mattered in survival, now let's compare sex and a 2nd feature
fig, qaxis = plt.subplots(1,3,figsize=(14,12))

sns.barplot(x = 'Sex_Code', y = 'Survived', hue = 'Embarked', data=titanic_train, ax = qaxis[0])
axis1.set_title('Sex vs Embarked Survival Comparison')

sns.barplot(x = 'Sex_Code', y = 'Survived', hue = 'Pclass', data=titanic_train, ax  = qaxis[1])
axis2.set_title('Sex vs Pclass Survival Comparison')

sns.barplot(x = 'Sex_Code', y = 'Survived', hue = 'IsAlone', data=titanic_train, ax  = qaxis[2])
axis3.set_title('Sex vs IsAlone Survival Comparison')



#more side-by-side comparisons
fig, (maxis1, maxis2) = plt.subplots(1, 2,figsize=(14,12))

#how does family size factor with sex & survival compare
sns.pointplot(x="FamilySize", y="Survived", hue="Sex", data=titanic_train,
              palette={"male": "blue", "female": "pink"},
              markers=["*", "o"], linestyles=["-", "--"], ax = maxis1)

#how does class factor with sex & survival compare
sns.pointplot(x="Pclass", y="Survived", hue="Sex", data=titanic_train,
              palette={"male": "blue", "female": "pink"},
              markers=["*", "o"], linestyles=["-", "--"], ax = maxis2)


#how does embark port factor with class, sex, and survival compare
#facetgrid: https://seaborn.pydata.org/generated/seaborn.FacetGrid.html
e = sns.FacetGrid(titanic_train, col = 'Embarked')
e.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', ci=95.0, palette = 'deep')
e.add_legend()


#plot distributions of age of passengers who survived or did not survive
a = sns.FacetGrid( titanic_train, hue = 'Survived', aspect=4 )
a.map(sns.kdeplot, 'Age', shade= True )
a.set(xlim=(0 , titanic_train['Age'].max()))
a.add_legend()

#histogram comparison of sex, class, and age by survival
h = sns.FacetGrid(titanic_train, row = 'Sex', col = 'Pclass', hue = 'Survived')
h.map(plt.hist, 'Age', alpha = .75)
h.add_legend()


#pair plots of entire dataset
pp = sns.pairplot(titanic_train, hue = 'Survived', palette = 'deep', size=1.2, diag_kind = 'kde', diag_kws=dict(shade=True), plot_kws=dict(s=10) )
pp.set(xticklabels=[])


#correlation heatmap of dataset
def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)

    _ = sns.heatmap(
        df.corr(),
        cmap = colormap,
        square=True,
        cbar_kws={'shrink':.9 },
        ax=ax,
        annot=True,
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )

    plt.title('Pearson Correlation of Features', y=1.05, size=15)

correlation_heatmap(titanic_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# ...

# %%
#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics


#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.plotting import scatter_matrix
import random

data1_x_calc = ['Sex_Code','Pclass', 'Embarked_Code', 'Title_Code','SibSp', 'Parch', 'Age_Code', 'Fare_Code','FamilySize', 'IsAlone']
Target = ['Survived']

train1_x, test1_x, train1_y, test1_y = model_selection.train_test_split(titanic_train[data1_x_calc],
                                                                        titanic_train[Target],
                                                                        stratify=titanic_train[Target],
                                                                        test_size=0.3, random_state = 42)

print("Data1 Shape: {}".format(titanic_train.shape))
print("Train1 Shape: {}".format(train1_x.shape))
print("Test1 Shape: {}".format(test1_x.shape))

#xgboost: http://xgboost.readthedocs.io/en/latest/model.html
model = svm.SVC()
#model = tree.DecisionTreeClassifier()

model.fit(train1_x, train1_y)

pred_y = model.predict(test1_x)

cf_matrix_TREE = confusion_matrix(test1_y, pred_y)

print("TREE RESULT", "-"*60)
print(cf_matrix_TREE)

TN, FP, FN, TP = cf_matrix_TREE.ravel()

print(TN,FP,FN,TP)

#Existem métodos prontos para fazer esses cálculos, prefira sempre o uso de métodos prontos


acuracia = (TP+TN) / (TN + FP + FN + TP)
print(acuracia)
sensibilidade = TP / (TP + FN)
print(sensibilidade)
especificidade = TN / (TN + FP)
print(especificidade)
precisao = TP / (TP + FP)
print(precisao)

import math
phi = ( (TP*TN) - (FP*FN) )  / math.sqrt( (TP + FP) * (TP + FN) * (TN + FP) * (TN + FN) )


from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(test1_y, pred_y)
auc = metrics.auc(fpr, tpr)
print(auc)
# Out:
# Data1 Shape: (891, 22)
# Train1 Shape: (623, 10)
# Test1 Shape: (268, 10)
# TREE RESULT ------------------------------------------------------------
# [[148  17]
#  [ 35  68]]
# 148 17 35 68
# 0.8059701492537313
# 0.6601941747572816
# 0.896969696969697
# 0.8
# 0.7785819358634893
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
MLA = [
    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),

    #Gaussian Processes
    gaussian_process.GaussianProcessClassifier(),

    #GLM
    linear_model.LogisticRegressionCV(),
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),

    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),

    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),

    #SVM
    svm.SVC(probability=True),
    svm.NuSVC(probability=True),
    svm.LinearSVC(),

    #Trees
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),

    #Discriminant Analysis
    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis(),


    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
    XGBClassifier()
    ]

#split dataset in cross-validation with this splitter class: http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit
#note: this is an alternative to train_test_split
cv_split = model_selection.ShuffleSplit(n_splits = 10, test_size = .3, train_size = .6, random_state = 0 ) # run model 10x with 60/30 split intentionally leaving out 10%

#create table to compare MLA metrics
MLA_columns = ['MLA Name', 'MLA Parameters','MLA Train Accuracy Mean', 'MLA Test Accuracy Mean', 'MLA Test Accuracy 3*STD' ,'MLA Time']
MLA_compare = pd.DataFrame(columns = MLA_columns)


#Selecionando colunas para treinamento
X = titanic_train[['Pclass', 'Sex_Code', 'Age_Code','SibSp','Parch', 'Fare', 'Embarked_Code']]
y = titanic_train['Survived']

#define x variables for original features aka feature selectio
#data1_xy =  Target + data1_x
#print('Original X Y: ', data1_xy, '\n')



#create table to compare MLA predictions
MLA_predict = titanic_train[Target]

#index through MLA and save performance to table
for alg in MLA:

    #set name and parameters
    MLA_name = alg.__class__.__name__

    #score model with cross validation: http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html#sklearn.model_selection.cross_validate
    cv_results = model_selection.cross_validate(alg, titanic_train[data1_x_calc], titanic_train[Target], cv  = cv_split)

    mla_data = {
        'MLA Name': MLA_name,
        'MLA Parameters': str(alg.get_params()),
        'MLA Time': cv_results['fit_time'].mean(),
        'MLA Test Accuracy Mean' : cv_results['test_score'].mean(),
        'MLA Test Accuracy 3*STD' : cv_results['test_score'].std()*3
        }

    MLA_compare = MLA_compare.append(mla_data, ignore_index = True)

#print and sort table: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
MLA_compare.sort_values(by = ['MLA Test Accuracy Mean'], ascending = False, inplace = True)
MLA_compare
#MLA_predict
sns.set(style="whitegrid")
#barplot using https://seaborn.pydata.org/generated/seaborn.barplot.html
sns.barplot(x='MLA Test Accuracy Mean', y = 'MLA Name', data = MLA_compare, color = 'g')
#prettify using pyplot: https://matplotlib.org/api/pyplot_api.html
plt.title('Machine Learning Algorithm Accuracy Score \n')
plt.xlabel('Accuracy Score (%)')
plt.ylabel('Algorithm')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#handmade data model using brain power (and Microsoft Excel Pivot Tables for quick calculations)
def mytree(df):

    #initialize table to store predictions
    Model = pd.DataFrame(data = {'Predict':[]})
    male_title = ['Master'] #survived titles

    for index, row in df.iterrows():

        #Question 1: Were you on the Titanic; majority died
        Model.loc[index, 'Predict'] = 0

        #Question 2: Are you female; majority survived
        if (df.loc[index, 'Sex'] == 'female'):
                  Model.loc[index, 'Predict'] = 1

        #Question 3A Female - Class and Question 4 Embarked gain minimum information

        #Question 5B Female - FareBin; set anything less than .5 in female node decision tree back to 0
        if ((df.loc[index, 'Sex'] == 'female') &
            (df.loc[index, 'Pclass'] == 3) &
            (df.loc[index, 'Embarked'] == 'S')  &
            (df.loc[index, 'Fare'] > 8)

           ):
                  Model.loc[index, 'Predict'] = 0

        #Question 3B Male: Title; set anything greater than .5 to 1 for majority survived
        if ((df.loc[index, 'Sex'] == 'male') &
            (df.loc[index, 'Title'] in male_title)
            ):
            Model.loc[index, 'Predict'] = 1


    return Model


#model data
Tree_Predict = mytree(titanic_train)
print('Decision Tree Model Accuracy/Precision Score: {:.2f}%\n'.format(metrics.accuracy_score(titanic_train['Survived'], Tree_Predict)*100))
# Out:
# Decision Tree Model Accuracy/Precision Score: 82.04%
